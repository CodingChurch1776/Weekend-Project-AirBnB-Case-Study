# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidance to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this intire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to similate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('files/AB_NYC_2019.csv')
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# How many neighborhood groups are available and which shows up the most?
#There are five neighborhood groups available and Manhattan shows up 21661 times 


# ----------------------------------------------------------



# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import csv
# from collections import Counter

# air_bnb = pd.read_csv('files/AB_NYC_2019.csv')
# air_bnb.head()

# print (air_bnb.neighbourhood_group.nunique())

# air_bnb_group = air_bnb['neighbourhood_group']
# print(air_bnb_group)
# print(type(air_bnb_group))

# air_bnb['neighbourhood_group'].value_counts()['Manhattan']

# manhattan_count = air_bnb[air_bnb['neighbourhood_group'] = Manhattan]['neighbourhood_group'].count()
# print(manhattan_count)

# df = pd.read_csv('files/AB_NYC_2019.csv')
# df_result = df[df['neighbourhood_group'] == 'Manhattan'].count()
# print(df_result)

air_bnb.describe(include='all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %%
# Are private rooms the most popular in manhattan?
# No, Entire home/apartments are the most popular at 25409 separate listings - 
# number of ratings do not necessarily determine popularity unless we are given 
# data on how many of the ratings are positive vs. negative for each listing.
# Availability could be a greater factor in popularity, however I am taking the route 
# that the greater the number of a certain kind of housing - the more demand there is for it, 
# otherwise people would not put up a listing.

----------------------------------------------------


# print (air_bnb.room_type.nunique())
# air_bnb['room_type'].value_counts()['']
# air_bnb_column = air_bnb['room_type']
# print(air_bnb_column)

# print(air_bnb['room_type'].value_counts()['Private room']) = 22326
# print(air_bnb['room_type'].value_counts()['Entire home/apt']) = 25409
#print(air_bnb['room_type'].value_counts()['Shared room']) = 1160
# Out:
# 1160

# %%
# Which hosts are the busiest and based on their reviews?
#Row NYC and Louann in Queens are the busiest if measuring purely by number of reviews per month at 58.5 and 27.95 reviews per month respectively.
#Nalicia in Queens is second busiest in most sort options
#Louann in Queens is first and Nalicia in Queens is second when factoring in: ['last_review', 'reviews_per_month', 'number_of_reviews']
-----------------------------------------------------------------------

# reset_index = air_bnb.loc[ [0,1,2,3] ][['host_name', 'number_of_reviews', 'last_review', 'reviews_per_month']]
# print(reset_index)
# air_bnb.sort_values(by='reviews_per_month', ascending=False)
# air_bnb.sort_values(by=['last_review', 'reviews_per_month'], ascending=[False, False])
air_bnb.sort_values(by=['last_review', 'reviews_per_month', 'number_of_reviews'], ascending=[False, False, False])
# air_bnb.sort_values(by=['last_review', 'reviews_per_month', 'calculated_host_listings_count', 'number_of_reviews'], ascending=[False, False, False, False])
# Out:
#              id                                               name    host_id  \
# 38870  30423106                 Lou's Palace-So much for so little  228415932
# 28651  22176831      JFK 2 Comfort 5 Mins from JFK Private Bedroom  156684502
# 22469  18173787  Cute Tiny Room Family Home by LGA NO CLEANING FEE   26432133
# 45317  34673695                     Home SWEET Home for a day or 2  261563626
# 42665  33119863                                     Queens Studio.   42540127
# ...         ...                                                ...        ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg    6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %%
#Which neighorhood group has the highest average price?
# Manhattan has the highest average price at 196.87 



# ------------------------------------------------

# air_bnb.sort_values(by='neighbourhood_group', ascending=False)
# groups = air_bnb['neighbourhood_group']

# air_bnb.unique('')
# air_bnb.describe(include='all')
# _list = air_bnb[air_bnb['host_name'] == "Danielle"]
# danielle_list[danielle_list['neighbourhood_group'] == "Queens"]
# air_bnb['price'].describe()['mean']

# Manhatten, staten island, Bronx, Queens, Brooklyn
# no_manhattan_or_queens = no_manhattan[no_manhattan['neighbourhood_group'] != 'Queens']
# no_manhattan_or_queens[no_manhattan_or_queens['neighbourhood_group'] != 'Brooklyn']

# only_manhattan = air_bnb[air_bnb['neighbourhood_group'] == 'Manhattan']
# air_bnb[air_bnb['neighbourhood_group'] == 'Manhattan']

# only_manhattan['price'].describe()['mean'] = 196.8758

-----------------------------------------------

# only_staten_island = air_bnb[air_bnb['neighbourhood_group'] == 'Staten Island']
# air_bnb[air_bnb['neighbourhood_group'] == 'Staten Island']

# only_staten_island['price'].describe()['mean'] = 114.81

----------------------------------------------------------------

# only_bronx = air_bnb[air_bnb['neighbourhood_group'] == 'Bronx']
# air_bnb[air_bnb['neighbourhood_group'] == 'Bronx']

# only_bronx['price'].describe()['mean'] = 87.496

------------------------------------------------------------------
# only_queens = air_bnb[air_bnb['neighbourhood_group'] == 'Queens']
# # air_bnb[air_bnb['neighbourhood_group'] == 'Queens']

# only_queens['price'].describe()['mean'] = 99.517




--------------------------------
# # # air_bnb[air_bnb['neighbourhood_group'] == 'Brooklyn']

# only_brooklyn['price'].describe()['mean'] = 124.3832

# only_brooklyn.describe(include='all')
# Out:
# 2500600

# %%
# Which neighborhood group has the highest total price?
# Manhattan also has the highest total price at a value of 4264527
----------------------------------------------------------------------------------------

# only_manhattan = air_bnb[air_bnb['neighbourhood_group'] == 'Manhattan']
# # air_bnb[air_bnb['neighbourhood_group'] == 'Manhattan']

# # only_manhattan['price'].describe()['mean'] = 196.8758

# manhattan_price = only_manhattan['price']

# manhattan_price.sum() == 4264527


# -----------------------------------------------

# only_staten_island = air_bnb[air_bnb['neighbourhood_group'] == 'Staten Island']
# # air_bnb[air_bnb['neighbourhood_group'] == 'Staten Island']

# # only_staten_island['price'].describe()['mean'] = 114.81

# staten_island_price = only_staten_island['price']

# staten_island_price.sum() = 42825

# ----------------------------------------------------------------

# only_bronx = air_bnb[air_bnb['neighbourhood_group'] == 'Bronx']
# # air_bnb[air_bnb['neighbourhood_group'] == 'Bronx']

# # only_bronx['price'].describe()['mean'] = 87.496

# bronx_price = only_bronx['price']

# bronx_price.sum() == 95459


# ------------------------------------------------------------------
# only_queens = air_bnb[air_bnb['neighbourhood_group'] == 'Queens']
# # # air_bnb[air_bnb['neighbourhood_group'] == 'Queens']

# # only_queens['price'].describe()['mean'] = 99.517

# queens_price = only_queens['price']

# queens_price.sum() == 563867 


# --------------------------------
# only_brooklyn = air_bnb[air_bnb['neighbourhood_group'] == 'Brooklyn']
# # # # air_bnb[air_bnb['neighbourhood_group'] == 'Brooklyn']

# # only_brooklyn['price'].describe()['mean'] = 124.3832

# # only_brooklyn.describe(include='all')

# brooklyn_price = only_brooklyn['price']

# brooklyn_price.sum() = 2500600
# Out:
# 4264527

# %%
#Which top 5 hosts have the highest total price?
# These host_id's are the top 5 with the highest total price combining price per night x minimum number of nights:
# IDs = 20582832, 72390391, 5143901, 3906464, 4382127

-----------------------------------------------------------------------------------------

air_bnb.sort_values(by=['price', 'minimum_nights'], ascending=[False, False])
# Out:
#   File "<ipython-input-211-66ef6c81ab24>", line 4
#     -----------------------------------------------------------------------------------------
#                                                                                              ^
# SyntaxError: invalid syntax

# %%
# Who currently has no (zero) availability with a review count of 100 or more?
# these host id's are the top 4/5 from the 162 total hosts with zero availability and a review count 100 or higher: 1: 792159 2: 22959695 3: 121391142 4: 21641206 
-----
# --------------------------------------------------------------------------------------------------

# hope = air_bnb.sort_values(by=['availability_365', 'number_of_reviews'], ascending=[True, False])
# pd.set_option('display.max_rows', 20)
# hope.head(162)
# Out:
#              id                                               name    host_id  \
# 471      166172                    LG Private Room/Family Friendly     792159
# 9974    7670562       JFK 10 & LGA 15 MINUTES A/C  PRIVATE BEDROOM   22959695
# 9976    7675781  JFK 10 & LGA 15 MINUTES  AWAY  A/C PRIVATE BED...   22959695
# 22104  17779504  Relaxing Quiet Room Just 6 Mins from JFK Airport!  121391142
# 5876    4282178                     A Superhost SALE! DELUXE Room!   21641206
# ...         ...                                                ...        ...
# 19377  15462208       Spacious 2 Bedroom Apartment by Central Park   26073602
# 12375   9544914  King Bed, Private Room in Crown Heights, Comedian   22423049
# 16190  13065356      "Quaint-Essential" Living in the West Village   42399786
# 18230  14283546         Adorable Crown Heights Home Away From Home   84141923
# 19459  15523119                   3 bedroom, second floor and cozy   96148809
#
# ...

# %%
# What host has the highest total of prices and where are they located?
# Katharine from Queens in Astoria has the highest total of prices even though she has only one listing because the minimum number of nights is 100 at $10,000 for the price.

air_bnb.sort_values(by=['price', 'minimum_nights', 'calculated_host_listings_count'], ascending=[False, False, False])
# Out:
#              id                                               name    host_id  \
# 9151    7003697                Furnished room in Astoria apartment   20582832
# 29238  22436899                                1-BR Lincoln Center   72390391
# 17692  13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 12342   9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 40433  31340283  2br - The Heart of NYC: Manhattans Lower East ...    4382127
# ...         ...                                                ...        ...
# 25433  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 25753  20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 25794  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 25795  20639792  Contemporary bedroom in brownstone with nice view   86327101
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
#
# ...

# %%
# When did Danielle from Queens last receive a review?
# There are multiple top hits for a Danielle from Queens, the Danielle at host_id = 26432133 was the most frequent hit and 
# her most recent review was on 2019-07-08 at AirBnb ID: 18173787

------------------------------------------------------------

air_bnb['host_name'] == "Danielle"
danielle_list = air_bnb[air_bnb['host_name'] == "Danielle"]
danielle_list[danielle_list['neighbourhood_group'] == "Queens"]
# Out:
#              id                                               name    host_id  \
# 7086    5115372  Comfy Room Family Home LGA Airport NO CLEANING...   26432133
# 16349  13151075                    ASTORIA APARTMENT OUTDOOR SPACE   18051286
# 20403  16276632  Cozy Room Family Home LGA Airport NO CLEANING FEE   26432133
# 21517  17222454   Sun Room Family Home LGA Airport NO CLEANING FEE   26432133
# 22068  17754072                Bed in Family Home Near LGA Airport   26432133
# 22469  18173787  Cute Tiny Room Family Home by LGA NO CLEANING FEE   26432133
# 27021  21386105  Quiet & clean 1br haven with balcony near the ...  154256662
# 33861  26814763  One bedroom with full bed / 1 stop from Manhattan  201647469
#
#       host_name neighbourhood_group     neighbourhood  latitude  longitude  \
# 7086   Danielle              Queens     East Elmhurst  40.76374  -73.87103
# 16349  Danielle              Queens           Astoria  40.77221  -73.92901
# ...

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %%
# air_bnb.describe(include='all')
Answer for #1 = Sonder(NYC) has the most listings at 327 total listings count


---------------------------------------------------
air_bnb.sort_values(by='calculated_host_listings_count', ascending=False)
# Out:
#              id                                               name    host_id  \
# 39773  30937596         Sonder | 11th Ave | Contemporary 1BR + Gym  219517861
# 41463  32240788      Sonder | Stock Exchange | Serene 2BR + Lounge  219517861
# 41469  32240966       Sonder | Stock Exchange | Sleek 3BR + Lounge  219517861
# 38294  30181945         Sonder | 180 Water | Premier 1BR + Rooftop  219517861
# 41468  32240933     Sonder | Stock Exchange | Lively 1BR + Kitchen  219517861
# ...         ...                                                ...        ...
# 18593  14694447                                         near metro   91292951
# 18594  14694588           Spacious Studio Room in Flushing, Queens   91381742
# 18595  14695540      Private Suite · Sparkling Clean · Memory Foam   12061634
# 18596  14696215                       Entire 1 Bedroom in Gramercy   91393670
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %% [markdown]
# 2. How many listings have completely open availability?

# %%
Answer for #2 = 1295 listings have completely open availability
  
open = air_bnb.sort_values(by='availability_365', ascending=False)
open.head(1295)
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 11591   9024549                  Spacious & Lofted in Williamsburg    8313697
# 41757  32467835  SPACIOUS & COMFY 3 BDROM/2 BATH APT CLOSE 2 SU...  216419980
# 41747  32466179  Sonder | The Nash |  Classic 1BR + Fitness Center  219517861
# 41742  32463948                          Amazing East Village Loft  238779678
# ...         ...                                                ...        ...
# 19123  15206157  1Bdrm DELUXE Fully Renovated CONDO Wyndham Mid...   96098402
# 19393  15476794                             Charming Private House   99346083
# 19126  15206607   STUDIO Condo in luxurious Wyndham Midtown 45 NYC   96098402
# 18943  15049253   Queens Comfy Private Room (JFK-8mins) with porch   74331597
# 19091  15176641                   Near transportation private room   19923341
#
# ...

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %%
Answer for #3 = Entire Homes and Apartments have the highest number of review numbers with 25409 ratings listed
______________________________________________________________________________________________

# group by room type --- mean review numbers

# only_private_room = air_bnb[air_bnb['room_type'] == 'Private room']
# # # air_bnb[air_bnb['room_type'] == 'Private room']

# # private_room_review_total = only_private_room['number_of_reviews']

# # private_room_review_total.sum() == 538346


# only_private_room.describe(include='all') = 22326

# only_entire_home_apt = air_bnb[air_bnb['room_type'] == 'Entire home/apt']

# only_entire_home_apt.describe(include='all') = 25409



# -------------------------------------------------------------------------------

# only_shared_room = air_bnb[air_bnb['room_type'] == 'Shared room']

# only_shared_room.describe(include='all') == 1160
# Out:
#                   id                                             name  \
# count   1.160000e+03                                             1159
# unique           NaN                                             1149
# top              NaN  Amazing cozy and warm male room on Manhattan IV
# freq             NaN                                                3
# mean    2.300378e+07                                              NaN
# std     1.048369e+07                                              NaN
# min     1.204800e+04                                              NaN
# 25%     1.516417e+07                                              NaN
# 50%     2.535204e+07                                              NaN
# 75%     3.241397e+07                                              NaN
# max     3.648561e+07                                              NaN
#
#              host_id host_name neighbourhood_group   neighbourhood  \
# ...

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --

# %%
1. Which hosts are the busiest and based on their reviews? (this question was not in the notebook, but is addressed in question 4)
#Row NYC and Louann in Queens are the busiest if measuring purely by number of reviews per month at 58.5 and 27.95 reviews per month respectively.
#Nalicia in Queens is second busiest in most sort options
#Louann in Queens is first and Nalicia in Queens is second when factoring in: ['last_review', 'reviews_per_month', 'number_of_reviews']
------
2. How many neighborhood groups are available and which shows up the most?
#There are five neighborhood groups available: Manhattan, Staten Island, Bronx, Brooklyn and Queens. Manhattan shows up the most at 21661 times. 
------
3. Are private rooms the most popular in manhattan?
# No, Entire home/apartments are the most popular at 25409 separate listings - 
# number of ratings do not necessarily determine popularity unless we are given 
# data on how many of the ratings are positive vs. negative for each listing.
# Availability could be a greater factor in popularity, however I am taking the route 
# that the greater the number of a certain kind of housing - the more demand there is for it, 
# otherwise people would not bother putting up the listing.
------
4. Which hosts are the busiest and based on their reviews?
#Row NYC and Louann in Queens are the busiest if measuring purely by number of reviews per month at 58.5 and 27.95 reviews per month respectively.
#Nalicia in Queens is second busiest in most sorting options
#Louann in Queens is first and Nalicia in Queens is second when factoring in: ['last_review', 'reviews_per_month', 'number_of_reviews']
------
5. Which neighorhood group has the highest average price?
# Manhattan has the highest average price at 196.87 
-----
6. Which neighborhood group has the highest total price?
# Manhattan has the highest total price at a value of 4264527.00
------
7. Which top 5 hosts have the highest total price?
# These host_id's are the top 5 with the highest total price (combining price per night x minimum number of nights:)
# IDs = 20582832, 72390391, 5143901, 3906464, 4382127
------
8. Who currently has no (zero) availability with a review count of 100 or more?
# these host id-s are the top 4/5 from the 162 total hosts with zero availability at a review count 100 or higher: (1: 792159 2: 22959695 3: 121391142 4: 21641206)
-----
9. What host has the highest total of prices and where are they located?
# Katharine from Queens in Astoria has the highest total of prices even though she has only one listing because the minimum number of nights is 100 at $10,000 for the price.
-----
10. When did Danielle from Queens last receive a review?
# There are multiple top hits for a Danielle from Queens, the Danielle at host_id = 26432133 was the most frequent hit and 
# her most recent review was on 2019-07-08 at AirBnb ID: 18173787


# ----------------------------------------------------------

Further Questions:
Answer for #1 = Sonder(NYC) has the most listings at 327 total listings count
    
Answer for #2 = 1295 listings have completely open availability

Answer for #3 = Entire Homes and Apartments have the highest number of review numbers with 25409 ratings listed
# Out:
#   File "<ipython-input-234-ab396309095e>", line 1
#     1. Which hosts are the busiest and based on their reviews? (this question was not in the notebook, but is addressed in question 4)
#        ^
# SyntaxError: invalid syntax
